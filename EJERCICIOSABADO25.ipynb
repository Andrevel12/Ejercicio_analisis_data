# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# importar pandas

# %%
import pandas as pd

# %% [markdown]
# SE TRAE LA TABLA DE EXCEL

# %%
df_data= pd.read_excel("DATOS.xlsx")
display(df_data)
# Out:
#    Unnamed: 0              Unnamed: 1 Unnamed: 2  Unnamed: 3   Unnamed: 4
# 0         NaN                  Nombre        Año      Genero  Presupuesto
# 1         NaN                avengers       2010      Accion          400
# 2         NaN                     saw       2000      Terror          100
# 3         NaN                    cars       2012     Animada           50
# 4         NaN  donde estan las rubias       2003     Comedia           20
# 5         NaN          michel Jackson       2026  Documental          100

# %%
df_data_2= pd.read_csv("DATOS_CSV.csv")
display(df_data_2)
# Out:
#    Unnamed: 0              Unnamed: 1 Unnamed: 2  Unnamed: 3   Unnamed: 4
# 0         NaN                  Nombre        Año      Genero  Presupuesto
# 1         NaN                avengers       2010      Accion          400
# 2         NaN                     saw       2000      Terror          100
# 3         NaN                    cars       2012     Animada           50
# 4         NaN  donde estan las rubias       2003     Comedia           20
# 5         NaN          michel Jackson       2026  Documental          100

# %%
df_data["director"]=["andre","federico","armando","popeye","juan","felipe"]
display(df_data)
# Out:
#    Unnamed: 0              Unnamed: 1 Unnamed: 2  Unnamed: 3   Unnamed: 4  \
# 0         NaN                  Nombre        Año      Genero  Presupuesto
# 1         NaN                avengers       2010      Accion          400
# 2         NaN                     saw       2000      Terror          100
# 3         NaN                    cars       2012     Animada           50
# 4         NaN  donde estan las rubias       2003     Comedia           20
# 5         NaN          michel Jackson       2026  Documental          100
#
#    director
# 0     andre
# 1  federico
# 2   armando
# 3    popeye
# 4      juan
# 5    felipe

# %% [markdown]
# exportar a excel

# %%
df_data.to_excel("nuevo_archivo.xlsx")

# %% [markdown]
# exportar a csv

# %%
df_data.to_csv("archivo_csv.csv")
